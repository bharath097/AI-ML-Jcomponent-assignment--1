# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/ENB2012_data energy-efficient.csv')

# %%
from matplotlib import pyplot as p
Y1=df['Y1 Heating Load']
X1=df['X1 Relative Compactness']
p.plot(Y1,X1)

# %%
from matplotlib import pyplot as p
Y1=df['Y1 Heating Load']
X1=df['X2 Surface Area']
p.plot(Y1,X1)

# %%
from matplotlib import pyplot as p
Y1=df['Y1 Heating Load']
X1=df['X3 Wall Area']
p.plot(Y1,X1)

# %%
from matplotlib import pyplot as p
Y1=df['Y1 Heating Load']
X1=df['X4 Roof Area']
p.plot(Y1,X1)

# %%
from matplotlib import pyplot as p
Y1=df['Y1 Heating Load']
X1=df['X5 Overall Height']
p.plot(Y1,X1)

# %%
from matplotlib import pyplot as p
Y1=df['Y1 Heating Load']
X1=df['X6 Orientation']
p.plot(Y1,X1)

# %%
from matplotlib import pyplot as p
Y1=df['Y1 Heating Load']
X1=df['X7 Glazing Area']
p.plot(Y1,X1)

# %%
from matplotlib import pyplot as p
Y1=df['Y1 Heating Load']
X1=df['X8 Glazing Area Distribution']
p.plot(Y1,X1)
